# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# load in data for total number of positions 
positions = pd.read_csv("num_positions.csv")
positions_df = pd.DataFrame(positions)
positions_df = positions_df.iloc[50:]
positions_df
# Out:
#     years  total_22  total_25
# 50   2000  18057983  18057983
# 51   2001  16179623  16179623
# 52   2002  15821803  15821803
# 53   2003  17680211  17680211
# 54   2004  21669647  21669647
# 55   2005  26399777  26399777
# 56   2006  30723082  30723082
# 57   2007  35896483  35896483
# 58   2008  38787960  38787960
# 59   2009  35991023  35991023
# 60   2010  47412518  47412518
# 61   2011  52904928  52904928
# 62   2012  57126568  57126568
# 63   2013  59595626  59595626
# 64   2014  63578251  63578251
# 65   2015  65804711  65804711
# 66   2016  65593629  65593629
# 67   2017  67636363  67636363
# 68   2018  70120822  70120822
# 69   2019  67190042  67190042
# 70   2020  49231522  49231522
# 71   2021  48334495  48334495
# 72   2022  10285774  10285774

# %% [markdown]
# ## Data Importing

# %%
# load in data for total number of AI positions
AI_positions = pd.read_csv("AI_positions_total.csv")
AI_positions_df = pd.DataFrame(AI_positions)
AI_positions_df
# Out:
#     start_years   AI_22   AI_25
# 0          2000    5067    5567
# 1          2001    4247    4667
# 2          2002    3911    4297
# 3          2003    4398    4877
# 4          2004    5658    6315
# 5          2005    6951    7777
# 6          2006    9088   10116
# 7          2007   10663   11915
# 8          2008   11605   12850
# 9          2009   10238   11430
# 10         2010   15124   16874
# 11         2011   17686   19935
# 12         2012   21399   24177
# 13         2013   27013   30555
# 14         2014   36660   41985
# 15         2015   48883   56140
# 16         2016   67449   77125
# 17         2017   87500   99918
# 18         2018  108834  124518
# 19         2019  111138  129572
# 20         2020   87489  106490
# 21         2021   70898  102229
# 22         2022   12668   27173

# %%
# load in data for percentage of AI positions out of total positions
AI_perc = pd.read_csv("AI_perc.csv")
AI_perc_df = pd.DataFrame(AI_perc)
AI_perc_df
# Out:
#     start_years   AI_22   AI_25
# 0          2000  0.0822  0.0902
# 1          2001  0.0792  0.0870
# 2          2002  0.0762  0.0836
# 3          2003  0.0774  0.0858
# 4          2004  0.0824  0.0915
# 5          2005  0.0818  0.0918
# 6          2006  0.0953  0.1061
# 7          2007  0.0996  0.1113
# 8          2008  0.1049  0.1159
# 9          2009  0.1012  0.1128
# 10         2010  0.1174  0.1309
# 11         2011  0.1227  0.1381
# 12         2012  0.1359  0.1533
# 13         2013  0.1626  0.1838
# 14         2014  0.2095  0.2395
# 15         2015  0.2735  0.3133
# 16         2016  0.3996  0.4541
# 17         2017  0.4998  0.5685
# 18         2018  0.6062  0.6912
# 19         2019  0.6482  0.7528
# 20         2020  0.6771  0.8204
# 21         2021  0.5653  0.8085
# 22         2022  0.4253  0.9005

# %%
# load in data for total number of AI descriptions
AI_desc = pd.read_csv("AI_desc_total.csv")
AI_desc_df = pd.DataFrame(AI_desc)
AI_desc_df
# Out:
#     start_years   AI_22   AI_25
# 0          2000    5182    5710
# 1          2001    4358    4813
# 2          2002    3913    4327
# 3          2003    4443    4948
# 4          2004    5710    6387
# 5          2005    6909    7822
# 6          2006    9020   10117
# 7          2007   10591   11926
# 8          2008   11483   12765
# 9          2009   10036   11277
# 10         2010   14735   16593
# 11         2011   17219   19582
# 12         2012   21024   23961
# 13         2013   26454   30213
# 14         2014   36103   41726
# 15         2015   48225   55935
# 16         2016   68239   78629
# 17         2017   84687   98259
# 18         2018  102849  120345
# 19         2019  101852  122200
# 20         2020   76696   97546
# 21         2021   56708   91010
# 22         2022    8319   24078

# %%
# load in data for percentage of AI descriptions out of total positions
AI_desc_perc = pd.read_csv("AI_desc_perc.csv")
AI_desc_perc_df = pd.DataFrame(AI_desc_perc)
AI_desc_perc_df
# Out:
#     start_years  AI_22_desc  AI_25_desc
# 0          2000      0.0782      0.0862
# 1          2001      0.0757      0.0836
# 2          2002      0.0716      0.0792
# 3          2003      0.0737      0.0820
# 4          2004      0.0779      0.0871
# 5          2005      0.0777      0.0879
# 6          2006      0.0903      0.1012
# 7          2007      0.0949      0.1068
# 8          2008      0.0993      0.1103
# 9          2009      0.0949      0.1066
# 10         2010      0.1096      0.1234
# 11         2011      0.1149      0.1307
# 12         2012      0.1280      0.1458
# 13         2013      0.1526      0.1743
# 14         2014      0.1976      0.2284
# 15         2015      0.2576      0.2988
# 16         2016      0.3733      0.4301
# 17         2017      0.4560      0.5291
# 18         2018      0.5418      0.6340
# 19         2019      0.5637      0.6763
# 20         2020      0.5658      0.7196
# 21         2021      0.4308      0.6913
# ...

# %%
# load in data for total number of AI titles
AI_title = pd.read_csv("AI_title_total.csv")
AI_title_df = pd.DataFrame(AI_title)
AI_title_df
# Out:
#     start_years  AI_22  AI_25
# 0          2000    325    325
# 1          2001    278    278
# 2          2002    312    312
# 3          2003    286    286
# 4          2004    464    464
# 5          2005    529    529
# 6          2006    666    666
# 7          2007    750    750
# 8          2008    947    947
# 9          2009    910    910
# 10         2010   1434   1434
# 11         2011   1701   1701
# 12         2012   1975   1975
# 13         2013   2626   2626
# 14         2014   3668   3668
# 15         2015   5566   5566
# 16         2016   9133   9133
# 17         2017  15191  15191
# 18         2018  22359  22359
# 19         2019  25910  25910
# 20         2020  23834  23834
# 21         2021  24347  24347
# 22         2022   5961   5961

# %%
# load in data for percentage of AI titles out of all positions 
AI_title_perc = pd.read_csv("AI_title_perc.csv")
AI_title_perc_df = pd.DataFrame(AI_title_perc)
AI_title_perc_df
# Out:
#     start_years  AI_22_title  AI_25_title
# 0          2000       0.0049       0.0049
# 1          2001       0.0048       0.0048
# 2          2002       0.0057       0.0057
# 3          2003       0.0047       0.0047
# 4          2004       0.0063       0.0063
# 5          2005       0.0059       0.0059
# 6          2006       0.0067       0.0067
# 7          2007       0.0067       0.0067
# 8          2008       0.0082       0.0082
# 9          2009       0.0086       0.0086
# 10         2010       0.0107       0.0107
# 11         2011       0.0114       0.0114
# 12         2012       0.0120       0.0120
# 13         2013       0.0152       0.0152
# 14         2014       0.0201       0.0201
# 15         2015       0.0297       0.0297
# 16         2016       0.0500       0.0500
# 17         2017       0.0818       0.0818
# 18         2018       0.1178       0.1178
# 19         2019       0.1434       0.1434
# 20         2020       0.1758       0.1758
# ...

# %%
# load in data for number of positions with descriptions and no AI signals in 2022 and number of descriptions with AI signals in 2025 
AI_desc_22_25 = pd.read_csv("AI_desc_22_25.csv")
AI_desc_22_25_df = pd.DataFrame(AI_desc_22_25)
AI_desc_22_25_df.rename(columns= {'AI_nodesc_22_desc_25' : 'AI_desc_22_25'}, inplace = True)
AI_desc_22_25_df
# Out:
#     start_years  AI_desc_22_25
# 0          2000            146
# 1          2001            174
# 2          2002            190
# 3          2003            177
# 4          2004            279
# 5          2005            374
# 6          2006            316
# 7          2007            500
# 8          2008            514
# 9          2009            537
# 10         2010            746
# 11         2011           1019
# 12         2012           1372
# 13         2013           1673
# 14         2014           2350
# 15         2015           3024
# 16         2016           3943
# 17         2017           4769
# 18         2018           6748
# 19         2019           7982
# 20         2020           8414
# 21         2021          11557
# 22         2022           3730

# %%
# load in data for percentage of positions with descriptions and no AI signals in 2022 and number of descriptions with AI signals in 2025 
AI_desc_22_25_perc = pd.read_csv("AI_desc_22_25_perc.csv")
AI_desc_22_25_perc_df = pd.DataFrame(AI_desc_22_25_perc)
AI_desc_22_25_perc_df
# Out:
#     start_years  AI_desc_22_desc_25
# 0          2000              0.0022
# 1          2001              0.0030
# 2          2002              0.0035
# 3          2003              0.0029
# 4          2004              0.0038
# 5          2005              0.0042
# 6          2006              0.0032
# 7          2007              0.0045
# 8          2008              0.0044
# 9          2009              0.0051
# 10         2010              0.0055
# 11         2011              0.0068
# 12         2012              0.0084
# 13         2013              0.0097
# 14         2014              0.0129
# 15         2015              0.0162
# 16         2016              0.0216
# 17         2017              0.0257
# 18         2018              0.0355
# 19         2019              0.0442
# 20         2020              0.0621
# 21         2021              0.0878
# 22         2022              0.1195

# %%
# load in data for number of descriptions containing AI signals in 2025, but no descriptions present in 2022 
AI_nodesc_22_desc_25 = pd.read_csv("AI_nodesc_22_desc_25.csv")
AI_nodesc_22_desc_25_df = pd.DataFrame(AI_nodesc_22_desc_25)
AI_nodesc_22_desc_25_df
# Out:
#     start_years  AI_nodesc_22_desc_25
# 0          2000                   489
# 1          2001                   340
# 2          2002                   277
# 3          2003                   402
# 4          2004                   529
# 5          2005                   698
# 6          2006                   935
# 7          2007                  1007
# 8          2008                  1036
# 9          2009                   957
# 10         2010                  1509
# 11         2011                  1755
# 12         2012                  2147
# 13         2013                  2857
# 14         2014                  4299
# 15         2015                  6202
# 16         2016                  8624
# 17         2017                 11911
# 18         2018                 14667
# 19         2019                 16927
# 20         2020                 16641
# 21         2021                 27130
# 22         2022                 12853

# %%
# load in data for percentage of descriptions containing AI signals in 2025, but no descriptions present in 2022 
AI_nodesc_22_desc_25_perc = pd.read_csv("AI_nodesc_22_desc_25_perc.csv")
AI_nodesc_22_desc_25_perc_df = pd.DataFrame(AI_nodesc_22_desc_25_perc)
AI_nodesc_22_desc_25_perc_df
# Out:
#     start_years   AI_25
# 0          2000  0.0074
# 1          2001  0.0059
# 2          2002  0.0051
# 3          2003  0.0067
# 4          2004  0.0072
# 5          2005  0.0078
# 6          2006  0.0094
# 7          2007  0.0090
# 8          2008  0.0090
# 9          2009  0.0090
# 10         2010  0.0112
# 11         2011  0.0117
# 12         2012  0.0131
# 13         2013  0.0165
# 14         2014  0.0235
# 15         2015  0.0331
# 16         2016  0.0472
# 17         2017  0.0641
# 18         2018  0.0773
# 19         2019  0.0937
# 20         2020  0.1228
# 21         2021  0.2061
# 22         2022  0.4116

# %%
# load in data for number of descriptions with AI signals present in 2022, but no descriptions in 2025 db
AI_desc_22_nodesc_25 = pd.read_csv("AI_desc_22_nodesc_25.csv")
AI_desc_22_nodesc_25_df = pd.DataFrame(AI_desc_22_nodesc_25)
AI_desc_22_nodesc_25_df
# Out:
#     start_years  AI_desc_22_nodesc_25
# 0          2000                    26
# 1          2001                     8
# 2          2002                    13
# 3          2003                     9
# 4          2004                    39
# 5          2005                    42
# 6          2006                    33
# 7          2007                    32
# 8          2008                    74
# 9          2009                    51
# 10         2010                    79
# 11         2011                    55
# 12         2012                    92
# 13         2013                   125
# 14         2014                   181
# 15         2015                   271
# 16         2016                   437
# 17         2017                   615
# 18         2018                   672
# 19         2019                   819
# 20         2020                   695
# 21         2021                   572
# 22         2022                    83

# %%
# load in data for percentage of descriptions with AI signals present in 2022, but no descriptions in 2025 db
AI_desc_22_nodesc_25_perc = pd.read_csv("AI_desc_22_nodesc_25_perc.csv")
AI_desc_22_nodesc_25_perc_df = pd.DataFrame(AI_desc_22_nodesc_25_perc)
AI_desc_22_nodesc_25_perc_df.rename(columns = {'AI_desc_22_desc_25' : 'AI_desc_22_nodesc_25'}, inplace = True)
AI_desc_22_nodesc_25_perc_df
# Out:
#     start_years  AI_desc_22_nodesc_25
# 0          2000                0.0004
# 1          2001                0.0001
# 2          2002                0.0002
# 3          2003                0.0001
# 4          2004                0.0005
# 5          2005                0.0005
# 6          2006                0.0003
# 7          2007                0.0003
# 8          2008                0.0006
# 9          2009                0.0005
# 10         2010                0.0006
# 11         2011                0.0004
# 12         2012                0.0006
# 13         2013                0.0007
# 14         2014                0.0010
# 15         2015                0.0014
# 16         2016                0.0024
# 17         2017                0.0033
# 18         2018                0.0035
# 19         2019                0.0045
# 20         2020                0.0051
# 21         2021                0.0043
# 22         2022                0.0027

# %%
# load in data for number of descriptions with AI signals present in 2022 AND in 2025 db
AI_desc_nochange = pd.read_csv("AI_desc_nochange.csv")
AI_desc_nochange_df = pd.DataFrame(AI_desc_nochange)
AI_desc_nochange_df
# Out:
#     start_years  AI_22_25
# 0          2000      5075
# 1          2001      4299
# 2          2002      3860
# 3          2003      4369
# 4          2004      5579
# 5          2005      6750
# 6          2006      8866
# 7          2007     10419
# 8          2008     11215
# 9          2009      9783
# 10         2010     14338
# 11         2011     16808
# 12         2012     20442
# 13         2013     25683
# 14         2014     35077
# 15         2015     46709
# 16         2016     66062
# 17         2017     81579
# 18         2018     98930
# 19         2019     97291
# 20         2020     72491
# 21         2021     52323
# 22         2022      7495

# %%
# Subtract number of descriptions w AI in 2022 from number in 2025 db and use that as denominator to find %
# of descriptions being added 
desc_denom = np.array(AI_desc.AI_25)
AI_nodesc_22_desc_25_arr = np.array(AI_nodesc_22_desc_25_df.AI_nodesc_22_desc_25)
new_AI_nodesc_22_desc_25 = np.round((AI_nodesc_22_desc_25_arr/desc_denom)*100.0, 4)
new_AI_nodesc_22_desc_25_df = pd.DataFrame(AI_nodesc_22_desc_25_df.start_years).join(pd.DataFrame(new_AI_nodesc_22_desc_25))
new_AI_nodesc_22_desc_25_df.rename(columns={0: '% Desc Added in 2025 DB'}, inplace = True)
new_AI_nodesc_22_desc_25_df
# Out:
#     start_years  % Desc Added in 2025 DB
# 0          2000                   8.5639
# 1          2001                   7.0642
# 2          2002                   6.4017
# 3          2003                   8.1245
# 4          2004                   8.2824
# 5          2005                   8.9235
# 6          2006                   9.2419
# 7          2007                   8.4437
# 8          2008                   8.1159
# 9          2009                   8.4863
# 10         2010                   9.0942
# 11         2011                   8.9623
# 12         2012                   8.9604
# 13         2013                   9.4562
# 14         2014                  10.3029
# 15         2015                  11.0879
# 16         2016                  10.9680
# 17         2017                  12.1220
# 18         2018                  12.1875
# 19         2019                  13.8519
# 20         2020                  17.0596
# 21         2021                  29.8099
# ...

# %%
# Use desc_denom as denominator to find %
# of descriptions being changed
AI_desc_22_desc_25_arr = np.array(AI_desc_22_25_df.AI_desc_22_25)
new_AI_desc_22_desc_25 = np.round((AI_desc_22_desc_25_arr/desc_denom)*100.0, 4)
new_AI_desc_22_desc_25_df = pd.DataFrame(AI_desc_22_25_df.start_years).join(pd.DataFrame(new_AI_desc_22_desc_25))
new_AI_desc_22_desc_25_df.rename(columns={0: '% Desc Changed in 2025 DB'}, inplace = True)
new_AI_desc_22_desc_25_df
# Out:
#     start_years  % Desc Changed in 2025 DB
# 0          2000                     2.5569
# 1          2001                     3.6152
# 2          2002                     4.3910
# 3          2003                     3.5772
# 4          2004                     4.3682
# 5          2005                     4.7814
# 6          2006                     3.1235
# 7          2007                     4.1925
# 8          2008                     4.0266
# 9          2009                     4.7619
# 10         2010                     4.4959
# 11         2011                     5.2038
# 12         2012                     5.7260
# 13         2013                     5.5374
# 14         2014                     5.6320
# 15         2015                     5.4063
# 16         2016                     5.0147
# 17         2017                     4.8535
# 18         2018                     5.6072
# 19         2019                     6.5319
# 20         2020                     8.6257
# ...

# %%
# Use desc_denom as denominator to find %
# of descriptions that did not change
AI_desc_nochange_arr = np.array(AI_desc_nochange_df.AI_22_25)
new_AI_desc_nochange = np.round((AI_desc_nochange_arr/desc_denom)*100.0, 4)
new_AI_desc_nochange_df = pd.DataFrame(AI_desc_nochange_df.start_years).join(pd.DataFrame(new_AI_desc_nochange))
new_AI_desc_nochange_df.rename(columns={0: '% Desc Not Changed in 2025 DB'}, inplace = True)
new_AI_desc_nochange_df
# Out:
#     start_years  % Desc Not Changed in 2025 DB
# 0          2000                        88.8792
# 1          2001                        89.3206
# 2          2002                        89.2073
# 3          2003                        88.2983
# 4          2004                        87.3493
# 5          2005                        86.2951
# 6          2006                        87.6347
# 7          2007                        87.3637
# 8          2008                        87.8574
# 9          2009                        86.7518
# 10         2010                        86.4099
# 11         2011                        85.8339
# 12         2012                        85.3136
# 13         2013                        85.0065
# 14         2014                        84.0651
# 15         2015                        83.5059
# 16         2016                        84.0173
# 17         2017                        83.0245
# 18         2018                        82.2053
# ...

# %% [markdown]
# ## State Level Data

# %%
# load in data for percentage of AI positions for start year 2022 in all states
AI_positions_US_perc = pd.read_csv("AI_states_perc.csv")
AI_positions_US_perc_df = pd.DataFrame(AI_positions_US_perc)
AI_positions_US_perc_df_scaled = AI_positions_US_perc_df.loc[:, ['states', 'AI_states_25']]
# scale the values to be between -1 and 1
x = AI_positions_US_perc_df.AI_states_25
AI_positions_US_perc_df_scaled.AI_states_25 = (2*(x - x.min())/(x.max()-x.min()))-1
AI_positions_US_perc_df_scaled
# Out:
#    states  AI_states_25
# 0      AK     -0.818134
# 1      AL     -0.748866
# 2      AR     -0.808389
# 3      AZ     -0.630271
# 4      CA      0.114210
# 5      CO     -0.421717
# 6      CT     -0.674351
# 7      DC     -0.279358
# 8      DE     -0.571873
# 9      FL     -0.710484
# 10     GA     -0.435961
# 11     HI     -0.747667
# 12     IA     -0.823682
# 13     ID     -0.664905
# 14     IL     -0.455527
# 15     IN     -0.732449
# 16     KS     -0.835376
# 17     KY     -0.802766
# 18     LA     -0.860340
# 19     MA     -0.094869
# 20     MD     -0.499906
# 21     ME     -0.962817
# 22     MI     -0.563927
# 23     MN     -0.630646
# 24     MO     -0.779752
# 25     MS     -0.952997
# 26     MT     -0.806440
# 27     NC     -0.472994
# 28     ND     -0.724577
# 29     NE     -0.758462
# 30     NH     -0.883804
# 31     NJ     -0.584467
# 32     NM     -0.849245
# 33     NV     -0.703887
# 34     NY     -0.240826
# 35     OH     -0.695491
# 36     OK     -0.893699
# ...

# %%
AI_positions_US_perc_df_22 = AI_positions_US_perc_df.loc[:, ['states', 'AI_states_22']]
AI_positions_US_perc_df_25 = AI_positions_US_perc_df.loc[:, ['states', 'AI_states_25']]
Database = ['2022' if i <=50 else '2025' for i in range(2*len(AI_positions_US_perc_df_22))]
AI_positions_US_perc_df_22.rename(columns = {'AI_states_22':'AI %'}, inplace = True)
AI_positions_US_perc_df_25.rename(columns = {'AI_states_25':'AI %'}, inplace = True)
AI_positions_US_merged = pd.concat([AI_positions_US_perc_df_22, AI_positions_US_perc_df_25])
AI_positions_US_merged['Database'] = years
x = AI_positions_US_merged.iloc[:, 1]
AI_positions_US_merged.iloc[:, 1] = (2*(x - x.min())/(x.max()-x.min()))-1
AI_positions_US_merged
# Out:
#    states      AI % Database
# 0      AK -0.901861     2022
# 1      AL -0.845470     2022
# 2      AR -0.854504     2022
# 3      AZ -0.794907     2022
# 4      CA -0.425740     2022
# ..    ...       ...      ...
# 46     VT -0.675276     2025
# 47     WA  1.000000     2025
# 48     WI -0.681250     2025
# 49     WV -0.943754     2025
# 50     WY -0.568686     2025
#
# [102 rows x 3 columns]

# %%
# load in data for percentage of positions containing AI signals in the state of California 
AI_positions_CA_perc = pd.read_csv("AI_positions_CA_perc.csv")
AI_positions_CA_perc_df = pd.DataFrame(AI_positions_CA_perc)
AI_positions_CA_perc_df
# Out:
#     start_years  AI_CA_22  AI_CA_25
# 0          2000    0.0993    0.1109
# 1          2001    0.1033    0.1150
# 2          2002    0.0983    0.1103
# 3          2003    0.1047    0.1209
# 4          2004    0.1113    0.1231
# 5          2005    0.1006    0.1172
# 6          2006    0.1448    0.1637
# 7          2007    0.1443    0.1649
# 8          2008    0.1619    0.1808
# 9          2009    0.1591    0.1812
# 10         2010    0.1915    0.2165
# 11         2011    0.2089    0.2368
# 12         2012    0.2374    0.2728
# 13         2013    0.2889    0.3289
# 14         2014    0.3739    0.4312
# 15         2015    0.4778    0.5403
# 16         2016    0.7088    0.8048
# 17         2017    0.8501    0.9619
# 18         2018    1.0176    1.1503
# 19         2019    1.0528    1.2157
# 20         2020    1.1680    1.4002
# 21         2021    1.0165    1.4162
# 22         2022    0.7876    1.5655

# %%
# load in data for percentage of positions containing AI signals in the state of Washington 
AI_positions_WA_perc = pd.read_csv("AI_positions_WA_perc.csv")
AI_positions_WA_perc_df = pd.DataFrame(AI_positions_WA_perc)
AI_positions_WA_perc_df
# Out:
#     start_years  AI_WA_22  AI_WA_25
# 0          2000    0.1221    0.1374
# 1          2001    0.1463    0.1647
# 2          2002    0.1258    0.1547
# 3          2003    0.1404    0.1795
# 4          2004    0.1418    0.1566
# 5          2005    0.1801    0.1964
# 6          2006    0.1914    0.2250
# 7          2007    0.2151    0.2450
# 8          2008    0.2329    0.2566
# 9          2009    0.2075    0.2316
# 10         2010    0.3055    0.3456
# 11         2011    0.3024    0.3521
# 12         2012    0.4201    0.4891
# 13         2013    0.5012    0.5734
# 14         2014    0.6223    0.7210
# 15         2015    0.8405    0.9527
# 16         2016    1.1688    1.3510
# 17         2017    1.5663    1.7652
# 18         2018    1.8429    2.1094
# 19         2019    1.9365    2.2492
# 20         2020    2.0602    2.5655
# 21         2021    1.6139    2.4004
# 22         2022    1.3449    2.7444

# %%
# load in data for percentage of positions containing AI signals in the state of Florida 
AI_positions_FL_perc = pd.read_csv("AI_positions_FL_perc.csv")
AI_positions_FL_perc_df = pd.DataFrame(AI_positions_FL_perc)
AI_positions_FL_perc_df
# Out:
#     start_years  AI_FL_22  AI_FL_25
# 0          2000    0.0575    0.0578
# 1          2001    0.0656    0.0729
# 2          2002    0.0735    0.0786
# 3          2003    0.0586    0.0655
# 4          2004    0.0698    0.0802
# 5          2005    0.0667    0.0747
# 6          2006    0.0732    0.0800
# 7          2007    0.0749    0.0804
# 8          2008    0.0776    0.0827
# 9          2009    0.0633    0.0734
# 10         2010    0.0786    0.0840
# 11         2011    0.0797    0.0871
# 12         2012    0.0776    0.0844
# 13         2013    0.0785    0.0889
# 14         2014    0.0976    0.1111
# 15         2015    0.1164    0.1343
# 16         2016    0.1770    0.1987
# 17         2017    0.2236    0.2562
# 18         2018    0.2758    0.3096
# 19         2019    0.2787    0.3230
# 20         2020    0.2838    0.3391
# 21         2021    0.2759    0.3871
# 22         2022    0.2061    0.4629

# %%
# load in data for percentages of positions containing AI signals in the state of Texas
AI_positions_TX_perc = pd.read_csv("AI_positions_TX_perc.csv")
AI_positions_TX_perc_df = pd.DataFrame(AI_positions_TX_perc)
AI_positions_TX_perc_df.rename(columns = {'AI_FL_22': 'AI_TX_22', 'AI_FL_25':'AI_TX_25'}, inplace=True)
AI_positions_TX_perc_df
# Out:
#     start_years  AI_TX_22  AI_TX_25
# 0          2000    0.0937    0.1043
# 1          2001    0.0867    0.0930
# 2          2002    0.0882    0.0938
# 3          2003    0.0717    0.0797
# 4          2004    0.0998    0.1074
# 5          2005    0.0705    0.0787
# 6          2006    0.0882    0.0958
# 7          2007    0.0912    0.0977
# 8          2008    0.0969    0.1051
# 9          2009    0.0974    0.1037
# 10         2010    0.1009    0.1120
# 11         2011    0.1200    0.1315
# 12         2012    0.1328    0.1466
# 13         2013    0.1401    0.1534
# 14         2014    0.1737    0.1999
# 15         2015    0.2377    0.2694
# 16         2016    0.3287    0.3741
# 17         2017    0.4177    0.4753
# 18         2018    0.5384    0.6119
# 19         2019    0.5833    0.6743
# 20         2020    0.5694    0.6915
# 21         2021    0.4920    0.7150
# 22         2022    0.3891    0.8107

# %%
# load in percentage of positions containing AI signals in DC 
AI_positions_DC_perc = pd.read_csv("AI_positions_DC_perc.csv")
AI_positions_DC_perc_df = pd.DataFrame(AI_positions_DC_perc)
AI_positions_DC_perc_df.rename(columns = {'AI_FL_22':'AI_DC_22', 'AI_FL_25':'AI_DC_25'}, inplace = True)
AI_positions_DC_perc_df
# Out:
#     start_years  AI_DC_22  AI_DC_25
# 0          2000    0.0644    0.0790
# 1          2001    0.0711    0.0711
# 2          2002    0.0383    0.0511
# 3          2003    0.0581    0.0609
# 4          2004    0.0833    0.0971
# 5          2005    0.0522    0.0619
# 6          2006    0.0562    0.0715
# 7          2007    0.0643    0.0906
# 8          2008    0.0588    0.0697
# 9          2009    0.0860    0.0996
# 10         2010    0.0909    0.0944
# 11         2011    0.0741    0.1031
# 12         2012    0.1043    0.1333
# 13         2013    0.1118    0.1786
# 14         2014    0.1637    0.1943
# 15         2015    0.2002    0.2553
# 16         2016    0.3770    0.4381
# 17         2017    0.4105    0.4691
# 18         2018    0.5737    0.6521
# 19         2019    0.6467    0.7652
# 20         2020    0.7313    0.9368
# 21         2021    0.5406    0.8581
# 22         2022    0.3867    1.0377

# %%
# load in data for percentage of AI positions in the state of Colorado
AI_positions_CO_perc = pd.read_csv("AI_positions_CO_perc.csv")
AI_positions_CO_perc_df = pd.DataFrame(AI_positions_CO_perc)
AI_positions_CO_perc_df
# Out:
#     start_years  AI_CO_22  AI_CO_25
# 0          2000    0.0939    0.0985
# 1          2001    0.0995    0.1101
# 2          2002    0.0718    0.0806
# 3          2003    0.0624    0.0681
# 4          2004    0.0682    0.0819
# 5          2005    0.0627    0.0705
# 6          2006    0.0643    0.0747
# 7          2007    0.0819    0.0922
# 8          2008    0.0735    0.0830
# 9          2009    0.0820    0.0884
# 10         2010    0.0872    0.0988
# 11         2011    0.0992    0.1127
# 12         2012    0.1062    0.1145
# 13         2013    0.1050    0.1281
# 14         2014    0.1551    0.1714
# 15         2015    0.2251    0.2567
# 16         2016    0.3969    0.4352
# 17         2017    0.3644    0.4339
# 18         2018    0.3792    0.4531
# 19         2019    0.4770    0.5754
# 20         2020    0.5007    0.6490
# 21         2021    0.4408    0.6811
# 22         2022    0.4032    0.8494

# %%
# load in data for percentage of AI positions in the state of Massachusetts 
AI_positions_MA_perc = pd.read_csv("AI_positions_MA_perc.csv")
AI_positions_MA_perc_df = pd.DataFrame(AI_positions_MA_perc)
AI_positions_MA_perc_df
# Out:
#     start_years  AI_MA_22  AI_MA_25
# 0          2000    0.0989    0.1110
# 1          2001    0.0897    0.1055
# 2          2002    0.1321    0.1345
# 3          2003    0.0939    0.1037
# 4          2004    0.0922    0.1117
# 5          2005    0.1146    0.1422
# 6          2006    0.1183    0.1325
# 7          2007    0.1221    0.1445
# 8          2008    0.1415    0.1546
# 9          2009    0.1525    0.1740
# 10         2010    0.1597    0.1876
# 11         2011    0.1647    0.1972
# 12         2012    0.1890    0.2214
# 13         2013    0.2408    0.2658
# 14         2014    0.3060    0.3461
# 15         2015    0.4200    0.4882
# 16         2016    0.6026    0.6949
# 17         2017    0.8250    0.9307
# 18         2018    1.0182    1.1567
# 19         2019    1.0900    1.2552
# 20         2020    1.1864    1.3851
# 21         2021    0.9365    1.2894
# 22         2022    0.6431    1.2834

# %%
# load in data for percentage of AI positions in the state of West Viriginia 
AI_positions_WV_perc = pd.read_csv("AI_positions_WV_perc.csv")
AI_positions_WV_perc_df = pd.DataFrame(AI_positions_WV_perc)
AI_positions_WV_perc_df
# Out:
#     start_years  AI_WV_22  AI_WV_25
# 0          2000    0.1066    0.1066
# 1          2001    0.0523    0.0611
# 2          2002    0.0764    0.0764
# 3          2003    0.0164    0.0246
# 4          2004    0.0623    0.0692
# 5          2005    0.0171    0.0285
# 6          2006    0.0759    0.0961
# 7          2007    0.0459    0.0459
# 8          2008    0.1318    0.1318
# 9          2009    0.0546    0.0588
# 10         2010    0.0484    0.0517
# 11         2011    0.0284    0.0312
# 12         2012    0.0493    0.0570
# 13         2013    0.0557    0.0632
# 14         2014    0.1027    0.1101
# 15         2015    0.0975    0.1027
# 16         2016    0.1544    0.1625
# 17         2017    0.1098    0.1177
# 18         2018    0.1338    0.1441
# 19         2019    0.1498    0.1792
# 20         2020    0.1468    0.1631
# 21         2021    0.1126    0.1762
# 22         2022    0.0515    0.0772

# %%
# load in data for percentage of AI positions in the state of New York
AI_positions_NY_perc = pd.read_csv("AI_positions_NY_perc.csv")
AI_positions_NY_perc_df = pd.DataFrame(AI_positions_NY_perc)
AI_positions_NY_perc_df
# Out:
#     start_years  AI_NY_22  AI_NY_25
# 0          2000    0.1000    0.1118
# 1          2001    0.1040    0.1147
# 2          2002    0.0951    0.1011
# 3          2003    0.0920    0.1014
# 4          2004    0.1072    0.1212
# 5          2005    0.1012    0.1173
# 6          2006    0.1141    0.1294
# 7          2007    0.1271    0.1424
# 8          2008    0.1170    0.1327
# 9          2009    0.1113    0.1265
# 10         2010    0.1428    0.1585
# 11         2011    0.1342    0.1563
# 12         2012    0.1486    0.1697
# 13         2013    0.1805    0.2097
# 14         2014    0.2758    0.3154
# 15         2015    0.3693    0.4346
# 16         2016    0.5626    0.6454
# 17         2017    0.6463    0.7505
# 18         2018    0.8155    0.9368
# 19         2019    0.8330    0.9721
# 20         2020    0.9058    1.0877
# 21         2021    0.7221    1.0078
# 22         2022    0.5104    1.0899

# %% [markdown]
# ## City Level Data

# %%
# load in data for percentages of AI positions in SF region
AI_positions_SF_perc = pd.read_csv("AI_positions_SF_perc.csv") 
AI_positions_SF_perc_df = pd.DataFrame(AI_positions_SF_perc)
AI_positions_SF_perc_df
# Out:
#     start_years  AI_SF_22  AI_SF_25
# 0          2000    0.1591    0.1888
# 1          2001    0.1957    0.2203
# 2          2002    0.1628    0.1914
# 3          2003    0.2029    0.2637
# 4          2004    0.2027    0.2276
# 5          2005    0.2169    0.2560
# 6          2006    0.2659    0.3124
# 7          2007    0.3297    0.3769
# 8          2008    0.3729    0.4324
# 9          2009    0.3820    0.4324
# 10         2010    0.4397    0.4996
# 11         2011    0.5182    0.6243
# 12         2012    0.6189    0.7311
# 13         2013    0.8245    0.9753
# 14         2014    1.0753    1.2422
# 15         2015    1.3280    1.5608
# 16         2016    1.9544    2.2800
# 17         2017    2.6417    3.0455
# 18         2018    2.9092    3.3635
# 19         2019    2.9356    3.4518
# 20         2020    2.7269    3.4382
# 21         2021    2.2514    3.2439
# 22         2022    1.5999    3.5566

# %%
# load in data for percentage of AI positions in Seattle region 
AI_positions_Seattle_perc = pd.read_csv("AI_positions_Seattle_perc.csv")
AI_positions_Seattle_perc_df = pd.DataFrame(AI_positions_Seattle_perc)
AI_positions_Seattle_perc_df.rename(columns = {'AI_SF_22':'AI_Seattle_22', 'AI_SF_25':'AI_Seattle_25'}, inplace = True)
AI_positions_Seattle_perc_df
# Out:
#     start_years  AI_Seattle_22  AI_Seattle_25
# 0          2000         0.1060         0.1358
# 1          2001         0.1560         0.1718
# 2          2002         0.1431         0.1717
# 3          2003         0.1347         0.1684
# 4          2004         0.1340         0.1603
# 5          2005         0.2211         0.2365
# 6          2006         0.2142         0.2607
# 7          2007         0.2330         0.2606
# 8          2008         0.2824         0.3114
# 9          2009         0.2322         0.2613
# 10         2010         0.3842         0.4237
# 11         2011         0.3346         0.4064
# 12         2012         0.5289         0.6275
# 13         2013         0.6716         0.7579
# 14         2014         0.7903         0.9343
# 15         2015         1.0617         1.2314
# 16         2016         1.4881         1.7332
# 17         2017         2.0238         2.3243
# 18         2018         2.2212         2.5708
# ...

# %%
# load in data for percentage of AI positions in Miami region 
AI_positions_Miami_perc = pd.read_csv("AI_positions_Miami_perc.csv")
AI_positions_Miami_perc_df = pd.DataFrame(AI_positions_Miami_perc)
AI_positions_Miami_perc_df.rename(columns = {'AI_SF_22':'AI_Miami_22', 'AI_SF_25':'AI_Miami_25'}, inplace = True)
AI_positions_Miami_perc_df
# Out:
#     start_years  AI_Miami_22  AI_Miami_25
# 0          2000       0.0665       0.0606
# 1          2001       0.0886       0.0953
# 2          2002       0.0921       0.1013
# 3          2003       0.0346       0.0386
# 4          2004       0.0466       0.0516
# 5          2005       0.0402       0.0430
# 6          2006       0.0803       0.0902
# 7          2007       0.0656       0.0828
# 8          2008       0.0634       0.0734
# 9          2009       0.0616       0.0616
# 10         2010       0.0682       0.0737
# 11         2011       0.0636       0.0721
# 12         2012       0.0907       0.0985
# 13         2013       0.0951       0.1052
# 14         2014       0.1283       0.1408
# 15         2015       0.1259       0.1553
# 16         2016       0.1964       0.2143
# 17         2017       0.2716       0.3113
# 18         2018       0.3153       0.3593
# 19         2019       0.2826       0.3332
# 20         2020       0.4129       0.4906
# ...

# %%
# load in data for percentage of AI positions in San Diego region 
AI_positions_SD_perc = pd.read_csv("AI_positions_SD_perc.csv")
AI_positions_SD_perc_df = pd.DataFrame(AI_positions_SD_perc)
AI_positions_SD_perc_df
# Out:
#     start_years  AI_SD_22  AI_SD_25
# 0          2000    0.1422    0.1549
# 1          2001    0.1146    0.1354
# 2          2002    0.1286    0.1286
# 3          2003    0.0937    0.1109
# 4          2004    0.1055    0.1187
# 5          2005    0.1453    0.1643
# 6          2006    0.1199    0.1368
# 7          2007    0.1603    0.1914
# 8          2008    0.1725    0.1924
# 9          2009    0.1683    0.1917
# 10         2010    0.2302    0.2495
# 11         2011    0.2326    0.2623
# 12         2012    0.2664    0.3114
# 13         2013    0.2494    0.2841
# 14         2014    0.3756    0.4314
# 15         2015    0.3440    0.3907
# 16         2016    0.5613    0.6295
# 17         2017    0.7350    0.8417
# 18         2018    0.8673    0.9801
# 19         2019    0.9145    1.0377
# 20         2020    1.0266    1.1964
# 21         2021    0.9234    1.2570
# 22         2022    0.6737    1.2515

# %%
# load in data for percentage of AI positions in Los Angeles region 
AI_positions_LA_perc = pd.read_csv("AI_positions_LA_perc.csv")
AI_positions_LA_perc_df = pd.DataFrame(AI_positions_LA_perc)
AI_positions_LA_perc_df
# Out:
#     start_years  AI_LA_22  AI_LA_25
# 0          2000    0.1004    0.1081
# 1          2001    0.1249    0.1310
# 2          2002    0.0922    0.0942
# 3          2003    0.1242    0.1435
# 4          2004    0.0906    0.0999
# 5          2005    0.1000    0.1170
# 6          2006    0.1583    0.1739
# 7          2007    0.1588    0.1698
# 8          2008    0.1553    0.1791
# 9          2009    0.1324    0.1505
# 10         2010    0.1816    0.2030
# 11         2011    0.1432    0.1582
# 12         2012    0.1433    0.1693
# 13         2013    0.1891    0.2091
# 14         2014    0.2288    0.2573
# 15         2015    0.2666    0.3031
# 16         2016    0.5197    0.5905
# 17         2017    0.5220    0.5972
# 18         2018    0.6169    0.7045
# 19         2019    0.6263    0.7305
# 20         2020    0.7018    0.8516
# 21         2021    0.5661    0.8716
# 22         2022    0.3790    0.8334

# %%
# load in data for percentage of AI positions in Houston region 
AI_positions_Houston_perc = pd.read_csv("AI_positions_Houston_perc.csv")
AI_positions_Houston_perc_df = pd.DataFrame(AI_positions_Houston_perc)
AI_positions_Houston_perc_df
# Out:
#     start_years  AI_Houston_22  AI_Houston_25
# 0          2000         0.0826         0.1069
# 1          2001         0.0948         0.1005
# 2          2002         0.1163         0.1247
# 3          2003         0.0893         0.0863
# 4          2004         0.1027         0.1068
# 5          2005         0.0817         0.0804
# 6          2006         0.1089         0.1203
# 7          2007         0.1189         0.1256
# 8          2008         0.1278         0.1343
# 9          2009         0.1362         0.1437
# 10         2010         0.1483         0.1621
# 11         2011         0.1551         0.1706
# 12         2012         0.1815         0.1978
# 13         2013         0.1850         0.2025
# 14         2014         0.2210         0.2457
# 15         2015         0.2715         0.3071
# 16         2016         0.3283         0.3718
# 17         2017         0.4175         0.4732
# 18         2018         0.5329         0.5983
# ...

# %%
# load in data for percentage of AI positions in Austin region 
AI_positions_Austin_perc = pd.read_csv("AI_positions_Austin_perc.csv")
AI_positions_Austin_perc_df = pd.DataFrame(AI_positions_Austin_perc)
AI_positions_Austin_perc_df
# Out:
#     start_years  AI_Austin_22  AI_Austin_25
# 0          2000        0.1630        0.1793
# 1          2001        0.1669        0.1689
# 2          2002        0.1307        0.1350
# 3          2003        0.0927        0.1499
# 4          2004        0.1665        0.1898
# 5          2005        0.1136        0.1458
# 6          2006        0.1135        0.1259
# 7          2007        0.1278        0.1416
# 8          2008        0.1499        0.1742
# 9          2009        0.1604        0.1880
# 10         2010        0.1438        0.1668
# 11         2011        0.2296        0.2597
# 12         2012        0.2556        0.2910
# 13         2013        0.3067        0.3431
# 14         2014        0.3312        0.3968
# 15         2015        0.5117        0.6294
# 16         2016        0.7581        0.8791
# 17         2017        0.9273        1.0640
# 18         2018        1.2059        1.3980
# 19         2019        1.2538        1.4625
# ...

# %%
# load in data for percentage of AI positions in New York City region 
AI_positions_NYC_perc = pd.read_csv("AI_positions_NYC_perc.csv")
AI_positions_NYC_perc_df = pd.DataFrame(AI_positions_NYC_perc)
AI_positions_NYC_perc_df
# Out:
#     start_years  AI_NYC_22  AI_NYC_25
# 0          2000     0.1259     0.1524
# 1          2001     0.1322     0.1568
# 2          2002     0.1621     0.1738
# 3          2003     0.1580     0.1745
# 4          2004     0.1443     0.1710
# 5          2005     0.1234     0.1584
# 6          2006     0.1528     0.1744
# 7          2007     0.1613     0.1896
# 8          2008     0.1385     0.1733
# 9          2009     0.1726     0.1910
# 10         2010     0.1879     0.2029
# 11         2011     0.1757     0.2207
# 12         2012     0.2106     0.2474
# 13         2013     0.2524     0.2912
# 14         2014     0.3857     0.4464
# 15         2015     0.5091     0.6143
# 16         2016     0.6758     0.7987
# 17         2017     0.9339     1.0777
# 18         2018     1.1346     1.3191
# 19         2019     1.1623     1.3663
# 20         2020     1.0660     1.2851
# 21         2021     0.8487     1.1927
# 22         2022     0.6169     1.2874

# %%
# load in data for percentage of AI positions in the 100 major cities in the US as listed by https://www.biggestuscities.com/
AI_positions_cities_perc = pd.read_csv("AI_positions_cities_perc.csv")
AI_positions_cities_perc_df = pd.DataFrame(AI_positions_cities_perc)
AI_positions_cities_perc_df

# load in data from simplemaps for US cities' long and lat coordinates 
US_cities_geo = pd.read_csv("simplemaps_uscities_basicv1.91/uscities.csv")
US_cities_geo_df = pd.DataFrame(US_cities_geo, columns = ['city', 'state_id', 'lat', 'lng'])
US_cities_geo_df.rename(columns = {'state_id':'state'}, inplace = True)

# merge the two dfs together 
AI_positions_cities_geo = AI_positions_cities_perc_df.merge(US_cities_geo_df, on = ['city', 'state'], how = 'left')
AI_positions_cities_geo
# Out:
#    state            city  AI_cities_22  AI_cities_25      lat       lng
# 0     NM     Albuquerque        0.1353        0.2029  35.1054 -106.6465
# 1     TX       Arlington        0.2124        0.4780  32.6998  -97.1250
# 2     GA         Atlanta        0.5405        1.1808  33.7628  -84.4220
# 3     CO          Aurora        0.0923        0.4306  39.7083 -104.7237
# 4     TX          Austin        0.8398        1.8056  30.3005  -97.7522
# ..   ...             ...           ...           ...      ...       ...
# 80    AZ          Tucson        0.3360        0.6720  32.1541 -110.8787
# 81    OK           Tulsa        0.0203        0.2437  36.1283  -95.9042
# 82    VA  Virginia Beach        0.0697        0.1395  36.7335  -76.0435
# 83    KS         Wichita        0.1548        0.1548  37.6895  -97.3443
# 84    NC   Winston-Salem        0.0806        0.2820  36.1029  -80.2610
#
# [85 rows x 6 columns]

# %% [markdown]
# ## Gender

# %%
# load in data for % of AI positions between woman and men
AI_positions_gender = pd.read_csv("AI_positions_gender.csv")
AI_positions_gender_df = pd.DataFrame(AI_positions_gender)
AI_positions_gender_df
# Out:
#     start_years  AI_F_22  AI_M_22  AI_F_25  AI_M_25
# 0          2000   0.0175   0.0650   0.0186   0.0719
# 1          2001   0.0159   0.0639   0.0171   0.0705
# 2          2002   0.0162   0.0603   0.0175   0.0663
# 3          2003   0.0145   0.0629   0.0163   0.0693
# 4          2004   0.0149   0.0677   0.0169   0.0748
# 5          2005   0.0164   0.0654   0.0184   0.0733
# 6          2006   0.0189   0.0755   0.0209   0.0843
# 7          2007   0.0203   0.0793   0.0230   0.0883
# 8          2008   0.0197   0.0853   0.0219   0.0942
# 9          2009   0.0192   0.0822   0.0213   0.0919
# 10         2010   0.0242   0.0934   0.0271   0.1042
# 11         2011   0.0247   0.0986   0.0277   0.1112
# 12         2012   0.0268   0.1095   0.0306   0.1233
# 13         2013   0.0338   0.1290   0.0378   0.1463
# 14         2014   0.0442   0.1653   0.0509   0.1886
# 15         2015   0.0585   0.2145   0.0677   0.2450
# 16         2016   0.1054   0.2928   0.1187   0.3340
# ...

# %% [markdown]
# ## Data Plotting

# %%
N = len(AI_positions_df)
ind = np.arange(N)
width = 0.3

# %%
plt.figure(figsize = (15, 10))

# plotting total number of positions
plt.subplot(2, 2, 1)
plt.bar(AI_positions_df.start_years, AI_positions_df.AI_22, width)

plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Number of Positions", fontsize = 16) 
plt.title("Number of Positions Posted", fontsize = 20) ;

# %%
plt.figure(figsize = (30, 20))
plt.suptitle("2022 Database vs 2025 Database", fontsize = 25) 

# first plot: total number of positions with AI
plt.subplot(2, 2, 1)
plt.bar(ind, AI_positions_df.AI_22, width, label = "2022 Database")
plt.bar(ind + width, AI_positions_df.AI_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_positions_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Number of Positions", fontsize = 16) 
plt.title("Number of Positions Containing AI Signals", fontsize = 20) 

plt.legend(loc = 'upper left')

# second plot: total number of descriptions with AI
plt.subplot(2, 2, 3)
plt.bar(ind, AI_desc_df.AI_22_desc, width, label = "2022 Database")
plt.bar(ind + width, AI_desc_df.AI_25_desc, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_desc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Number of Descriptions", fontsize = 16)
plt.title("Number of Descriptions Containing AI Signals", fontsize = 20)

plt.legend(loc = 'upper left')

# third plot: total number of titles with AI
plt.subplot(2, 2, 4)
plt.bar(ind, AI_title_df.AI_22_title, width, label = "2022 Database")
plt.bar(ind + width, AI_title_df.AI_25_title, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_title_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Number of Titles", fontsize = 16)
plt.title("Number of Titles Containing AI Signals", fontsize = 20)

plt.legend(loc = 'upper left')
plt.show()

# %%
plt.figure(figsize= (30, 20))
plt.suptitle("2022 Database vs 2025 Database", fontsize = 25)

# plotting percentage of positions with AI signals relative to total number of positions
plt.subplot(2, 2, 1)
plt.bar(ind, AI_perc_df.AI_22, width, label = "2022 Database")
plt.bar(ind + width, AI_perc_df.AI_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16)
plt.title("Percentage of Positions Containing AI Signals Relative to All Positions", fontsize = 20)

plt.legend(loc = 'upper left')

# plotting percentage of descriptions with AI signals relative to total number of positions
plt.subplot(2, 2, 3)
plt.bar(ind, AI_desc_perc_df.AI_22_desc, width, label = "2022 Database")
plt.bar(ind + width, AI_desc_perc_df.AI_25_desc, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_desc_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Descriptions", fontsize = 16)
plt.title("Percentage of Descriptions Containing AI Signals Relative to All Positions", fontsize = 20)

plt.legend(loc = 'upper left')

# plotting percentage of titles with AI signals relative to total number of positions
plt.subplot(2, 2, 4)
plt.bar(ind, AI_title_perc_df.AI_22_title, width, label = "2022 Database")
plt.bar(ind + width, AI_title_perc_df.AI_25_title, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_title_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Titles", fontsize = 16)
plt.title("Percentage of Titles Containing AI Signals Relative to All Positions", fontsize = 20)

plt.legend(loc = 'upper left')
plt.show()

# %%
# plotting descriptions present in both 2022 and 2025 databases where AI is not present in 2022 db, but is in 2025 db
plt.figure(figsize= (30, 20))
plt.suptitle("2022 Database vs 2025 Database", fontsize = 25)

plt.subplot(2, 2, 1)
plt.bar(ind, AI_desc_22_25_df.AI_desc_22_25, width)
#plt.bar(ind + width, AI_desc_22_25_df.AI_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_desc_22_25_df.start_years, ha = 'right', rotation = 45, fontsize = 12)
plt.yticks(fontsize = 12)
plt.xlabel("Start Years of Position", fontsize = 14)
plt.ylabel("Number of Descriptions", fontsize = 14)
plt.title("Number of Descriptions Present in 2022 DB with no AI signals, \n but Present in 2025 DB with AI Signals", fontsize = 16)
plt.ylim((0,30000))


# plotting descriptions not present in 2022 db, but present in 2025 db with AI signals present 
plt.subplot(2, 2, 2)
plt.bar(ind, AI_nodesc_22_desc_25_df.AI_nodesc_22_desc_25, width)

plt.xticks(ind + width/2, AI_nodesc_22_desc_25_df.start_years, ha = 'right', rotation = 45, fontsize = 12)
plt.yticks(fontsize = 12)
plt.xlabel("Start Years of Position", fontsize = 14)
plt.ylabel("Number of Descriptions", fontsize = 14)
plt.title("Number of Descriptions Not Present in 2022 DB, \n but Present in 2025 DB Containing AI Signals", fontsize = 16)
plt.ylim((0,30000))


# plotting descriptions present in 2022 db w AI signal, but not present in 2025 db
plt.subplot(2, 2, 3)
plt.bar(ind, AI_desc_22_nodesc_25_df.AI_desc_22_nodesc_25, width)

plt.xticks(ind + width/2, AI_desc_22_nodesc_25_df.start_years, ha = 'right', rotation = 45, fontsize = 12)
plt.yticks(fontsize = 12)
plt.xlabel("Start Years of Position", fontsize = 14)
plt.ylabel("Number of Descriptions", fontsize = 14)
plt.title("Number of Descriptions Present in 2022 DB Containing AI Signals, \n but Not Present in 2025 DB", fontsize = 16)
plt.ylim((0,30000))
# Out:
# (0.0, 30000.0)

# %%
# plotting percentage of descriptions present in both 2022 and 2025 databases where AI is not present in 2022 db, but is in 2025 db
plt.figure(figsize= (30, 20))
plt.suptitle("2022 Database vs 2025 Database", fontsize = 25)

plt.subplot(2, 2, 1)
plt.bar(ind, AI_desc_22_25_perc_df.AI_desc_22_desc_25, width)

plt.xticks(ind + width/2, AI_desc_22_25_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 12)
plt.yticks(fontsize = 12)
plt.xlabel("Start Years of Position", fontsize = 14)
plt.ylabel("Percentage of Descriptions", fontsize = 14)
plt.title("Percentage of Descriptions Present in 2022 DB with no AI signals, \n but Present in 2025 DB with AI Signals", fontsize = 16)
plt.ylim((0,0.4))


# plotting percentage of descriptions not present in 2022 db, but present in 2025 db with AI signals present 
plt.subplot(2, 2, 2)
plt.bar(ind, AI_nodesc_22_desc_25_perc_df.AI_25, width)

plt.xticks(ind + width/2, AI_nodesc_22_desc_25_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 12)
plt.yticks(fontsize = 12)
plt.xlabel("Start Years of Position", fontsize = 14)
plt.ylabel("Percentage of Descriptions", fontsize = 14)
plt.title("Percentage of Descriptions Not Present in 2022 DB, \n but Present in 2025 DB Containing AI Signals", fontsize = 16)

# plotting percentage of descriptions present in 2022 db with AI signals, but not present in 2025 db
plt.subplot(2, 2, 3)
plt.bar(ind, AI_desc_22_nodesc_25_perc_df.AI_desc_22_nodesc_25, width)

plt.xticks(ind + width/2, AI_desc_22_nodesc_25_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 12)
plt.yticks(fontsize = 12)
plt.xlabel("Start Years of Position", fontsize = 14)
plt.ylabel("Percentage of Descriptions", fontsize = 14)
plt.title("Percentage of Descriptions Present in 2022 DB Containing AI Signals, \n but Not Present in 2025 DB", fontsize = 16);
plt.ylim((0, 0.4));

# %%
# plotting percentage of descriptions changed, added, and remained the same with respect to AI descriptions in 2025 db
plt.figure(figsize= (15, 10))

plt.bar(ind, new_AI_nodesc_22_desc_25_df.iloc[:, 1], width, label = 'Descriptions Added')
plt.bar(ind + width, new_AI_desc_22_desc_25_df.iloc[:, 1], width, label = 'Descriptions Change')
plt.bar(ind + 2*width, new_AI_desc_nochange_df.iloc[:, 1], width, label = 'No Change')

plt.xticks(ind + 3*width/2, new_AI_nodesc_22_desc_25_df.start_years, ha = 'right', rotation = 45, fontsize = 12)
plt.yticks(fontsize = 12)
plt.xlabel("Start Years of Position", fontsize = 14)
plt.ylabel("Percentage of Descriptions", fontsize = 14)
plt.title("Percentage of Descriptions Changed, Added, and Unchanged \n with Respect to Descriptions in 2025 DB Containing AI Signals", fontsize = 16)

plt.legend(loc = 'best')
plt.show()

# %%
N = 1
ind = np.arange(N)
width = 0.3
# plotting percentage of descriptions changed, added, and remained the same with respect to AI descriptions in 2025 db, for start year 2022
plt.figure(figsize= (5, 5))

plt.bar(ind, new_AI_nodesc_22_desc_25_df.iloc[-1, 1], width, label = 'Descriptions Added')
plt.bar(ind + width, new_AI_desc_22_desc_25_df.iloc[-1, 1], width, label = 'Descriptions Change')
plt.bar(ind + 2*width, new_AI_desc_nochange_df.iloc[-1, 1], width, label = 'No Change')

plt.xticks([])
plt.yticks(fontsize = 8)
plt.xlabel("2022", fontsize = 12)
plt.ylabel("Percentage of Descriptions", fontsize = 12)
plt.title("Percentage of Descriptions Changed, Added, and Unchanged \n with Respect to Descriptions in 2025 DB Containing AI Signals", fontsize = 12)

plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# ## State Level Plotting

# %%
plt.figure(figsize = (30, 10))

plt.suptitle("2022 Database vs 2025 Database", fontsize = 25)

# plotting percentage of positions with AI signals relative to total number of positions
plt.subplot(1, 2, 1)
plt.bar(ind, AI_perc_df.AI_22, width, label = "2022 Database")
plt.bar(ind + width, AI_perc_df.AI_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16)
plt.title("Percentage of Positions Containing AI Signals in the US", fontsize = 20)
plt.ylim([0, 1.6])
plt.legend(loc = 'upper left')

# plotting percentage of positions with AI in CA
plt.subplot(1, 2, 2)
plt.bar(ind, AI_positions_CA_perc_df.AI_CA_22, width, label = "2022 Database")
plt.bar(ind + width, AI_positions_CA_perc_df.AI_CA_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_positions_CA_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16) 
plt.title("Percentage of Positions Containing AI Signals in CA", fontsize = 20)

plt.legend(loc = 'upper left')
plt.show()

# %%
plt.figure(figsize = (30, 10))

plt.suptitle("2022 Database vs 2025 Database", fontsize = 25)

# plotting percentage of positions with AI signals relative to total number of positions
plt.subplot(1, 2, 1)
plt.bar(ind, AI_perc_df.AI_22, width, label = "2022 Database")
plt.bar(ind + width, AI_perc_df.AI_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16)
plt.title("Percentage of Positions Containing AI Signals in the US", fontsize = 20)
plt.ylim([0, 3])
plt.legend(loc = 'upper left')

# plotting percentage of positions with AI in WA
plt.subplot(1, 2, 2)
plt.bar(ind, AI_positions_WA_perc_df.AI_WA_22, width, label = "2022 Database")
plt.bar(ind + width, AI_positions_WA_perc_df.AI_WA_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_positions_WA_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16) 
plt.title("Percentage of Positions Containing AI Signals in WA", fontsize = 20)
plt.ylim([0, 3])

plt.legend(loc = 'upper left')
plt.show()

# %%
plt.figure(figsize = (30, 10))

plt.suptitle("2022 Database vs 2025 Database", fontsize = 25)

# plotting percentage of positions with AI signals relative to total number of positions
plt.subplot(1, 2, 1)
plt.bar(ind, AI_perc_df.AI_22, width, label = "2022 Database")
plt.bar(ind + width, AI_perc_df.AI_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16)
plt.title("Percentage of Positions Containing AI Signals in the US", fontsize = 20)
plt.ylim([0, 1])
plt.legend(loc = 'upper left')

# plotting percentage of positions with AI in FL
plt.subplot(1, 2, 2)
plt.bar(ind, AI_positions_FL_perc_df.AI_FL_22, width, label = "2022 Database")
plt.bar(ind + width, AI_positions_FL_perc_df.AI_FL_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_positions_FL_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16) 
plt.title("Percentage of Positions Containing AI Signals in FL", fontsize = 20)
plt.ylim([0, 1])

plt.legend(loc = 'upper left')
plt.show()

# %%
plt.figure(figsize = (30, 10))

plt.suptitle("2022 Database vs 2025 Database", fontsize = 25)

# plotting percentage of positions with AI signals relative to total number of positions
plt.subplot(1, 2, 1)
plt.bar(ind, AI_perc_df.AI_22, width, label = "2022 Database")
plt.bar(ind + width, AI_perc_df.AI_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16)
plt.title("Percentage of Positions Containing AI Signals in the US", fontsize = 20)
plt.ylim([0, 1])
plt.legend(loc = 'upper left')

# plotting percentage of positions with AI in TX
plt.subplot(1, 2, 2)
plt.bar(ind, AI_positions_TX_perc_df.AI_TX_22, width, label = "2022 Database")
plt.bar(ind + width, AI_positions_TX_perc_df.AI_TX_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_positions_TX_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16) 
plt.title("Percentage of Positions Containing AI Signals in TX", fontsize = 20)
plt.ylim([0, 1])

plt.legend(loc = 'upper left')
plt.show()

# %%
plt.figure(figsize = (30, 10))

plt.suptitle("2022 Database vs 2025 Database", fontsize = 25)

# plotting percentage of positions with AI signals relative to total number of positions
plt.subplot(1, 2, 1)
plt.bar(ind, AI_perc_df.AI_22, width, label = "2022 Database")
plt.bar(ind + width, AI_perc_df.AI_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16)
plt.title("Percentage of Positions Containing AI Signals in the US", fontsize = 20)
plt.ylim([0, 1.1])
plt.legend(loc = 'upper left')

# plotting percentage of positions with AI in DC
plt.subplot(1, 2, 2)
plt.bar(ind, AI_positions_DC_perc_df.AI_DC_22, width, label = "2022 Database")
plt.bar(ind + width, AI_positions_DC_perc_df.AI_DC_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_positions_DC_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16) 
plt.title("Percentage of Positions Containing AI Signals in DC", fontsize = 20)
plt.ylim([0, 1.1])

plt.legend(loc = 'upper left')
plt.show()

# %%
plt.figure(figsize = (30, 10))

plt.suptitle("2022 Database vs 2025 Database", fontsize = 25)

# plotting percentage of positions with AI signals relative to total number of positions
plt.subplot(1, 2, 1)
plt.bar(ind, AI_perc_df.AI_22, width, label = "2022 Database")
plt.bar(ind + width, AI_perc_df.AI_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16)
plt.title("Percentage of Positions Containing AI Signals in the US", fontsize = 20)
plt.ylim([0, 1.1])
plt.legend(loc = 'upper left')

# plotting percentage of positions with AI in CO
plt.subplot(1, 2, 2)
plt.bar(ind, AI_positions_CO_perc_df.AI_CO_22, width, label = "2022 Database")
plt.bar(ind + width, AI_positions_CO_perc_df.AI_CO_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_positions_CO_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16) 
plt.title("Percentage of Positions Containing AI Signals in CO", fontsize = 20)
plt.ylim([0, 1.1])

plt.legend(loc = 'upper left')
plt.show()

# %%
plt.figure(figsize = (30, 10))

plt.suptitle("2022 Database vs 2025 Database", fontsize = 25)

# plotting percentage of positions with AI signals relative to total number of positions
plt.subplot(1, 2, 1)
plt.bar(ind, AI_perc_df.AI_22, width, label = "2022 Database")
plt.bar(ind + width, AI_perc_df.AI_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16)
plt.title("Percentage of Positions Containing AI Signals in the US", fontsize = 20)
plt.ylim([0, 1.5])
plt.legend(loc = 'upper left')

# plotting percentage of positions with AI in MA
plt.subplot(1, 2, 2)
plt.bar(ind, AI_positions_MA_perc_df.AI_MA_22, width, label = "2022 Database")
plt.bar(ind + width, AI_positions_MA_perc_df.AI_MA_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_positions_MA_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16) 
plt.title("Percentage of Positions Containing AI Signals in MA", fontsize = 20)
plt.ylim([0, 1.5])

plt.legend(loc = 'upper left')
plt.show()

# %%
plt.figure(figsize = (30, 10))

plt.suptitle("2022 Database vs 2025 Database", fontsize = 25)

# plotting percentage of positions with AI signals relative to total number of positions
plt.subplot(1, 2, 1)
plt.bar(ind, AI_perc_df.AI_22, width, label = "2022 Database")
plt.bar(ind + width, AI_perc_df.AI_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16)
plt.title("Percentage of Positions Containing AI Signals in the US", fontsize = 20)
plt.ylim([0, 1])
plt.legend(loc = 'upper left')

# plotting percentage of positions with AI in WV
plt.subplot(1, 2, 2)
plt.bar(ind, AI_positions_WV_perc_df.AI_WV_22, width, label = "2022 Database")
plt.bar(ind + width, AI_positions_WV_perc_df.AI_WV_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_positions_WV_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16) 
plt.title("Percentage of Positions Containing AI Signals in WV", fontsize = 20)
plt.ylim([0, 1])

plt.legend(loc = 'upper left')
plt.show()

# %%
plt.figure(figsize = (30, 10))

plt.suptitle("2022 Database vs 2025 Database", fontsize = 25)

# plotting percentage of positions with AI signals relative to total number of positions
plt.subplot(1, 2, 1)
plt.bar(ind, AI_perc_df.AI_22, width, label = "2022 Database")
plt.bar(ind + width, AI_perc_df.AI_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16)
plt.title("Percentage of Positions Containing AI Signals in the US", fontsize = 20)
plt.ylim([0, 1.2])
plt.legend(loc = 'upper left')

# plotting percentage of positions with AI in NY
plt.subplot(1, 2, 2)
plt.bar(ind, AI_positions_NY_perc_df.AI_NY_22, width, label = "2022 Database")
plt.bar(ind + width, AI_positions_NY_perc_df.AI_NY_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_positions_NY_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16) 
plt.title("Percentage of Positions Containing AI Signals in NY", fontsize = 20)
plt.ylim([0, 1.2])

plt.legend(loc = 'upper left')
plt.show()

# %%
# create a map of the US using a choropleth map where each state is shaded on a scale of AI representation in positions 
fig = px.choropleth(AI_positions_US_perc_df_scaled, locations = 'states', locationmode = "USA-states", scope = "usa", 
                    color = 'AI_states_25', color_continuous_scale="sunset", labels = {'AI_states_25':'AI %'}, )
fig.update_layout(title_text = "Map of Scaled AI Representation in Positions by State<br><sup>2022 Start Year, 2025 Database</sup>", title_font_family = "Times New Roman", title_font_size = 22,
                  title_font_color = "black", title_x = 0.45, )
fig.show()

# %%
# create a map of the US using a choropleth map where each state is shaded on a scale of AI representation in positions 
fig = px.choropleth(AI_positions_US_merged, locations = 'states', locationmode = "USA-states", scope = "usa", 
                    color = 'AI %', color_continuous_scale="sunset", animation_frame = 'Database')
fig.update_layout(title_text = "Map of Scaled AI Representation in Positions by State<br><sup>2022 Start Year</sup>", title_font_family = "Times New Roman", title_font_size = 22,
                  title_font_color = "black", title_x = 0.45, )
fig.show()

# %% [markdown]
# ## City Level Plotting

# %%
plt.figure(figsize = (30, 10))

plt.suptitle("2022 Database vs 2025 Database", fontsize = 25)

# plotting percentage of positions with AI in CA
plt.subplot(1, 2, 1)
plt.bar(ind, AI_positions_CA_perc_df.AI_CA_22, width, label = "2022 Database")
plt.bar(ind + width, AI_positions_CA_perc_df.AI_CA_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_positions_CA_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16) 
plt.title("Percentage of Positions Containing AI Signals in CA", fontsize = 20)
plt.ylim([0,3.7])

plt.legend(loc = 'upper left')

# plotting percentage of positions with AI in SF
plt.subplot(1, 2, 2)
plt.bar(ind, AI_positions_SF_perc_df.AI_SF_22, width, label = "2022 Database")
plt.bar(ind + width, AI_positions_SF_perc_df.AI_SF_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_positions_SF_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16) 
plt.title("Percentage of Positions Containing AI Signals in San Francisco Region", fontsize = 20)
plt.ylim([0, 3.7])

plt.legend(loc = 'upper left')
plt.show()

# %%
plt.figure(figsize = (30, 10))

plt.suptitle("2022 Database vs 2025 Database", fontsize = 25)

# plotting percentage of positions with AI in WA
plt.subplot(1, 2, 1)
plt.bar(ind, AI_positions_WA_perc_df.AI_WA_22, width, label = "2022 Database")
plt.bar(ind + width, AI_positions_WA_perc_df.AI_WA_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_positions_WA_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16) 
plt.title("Percentage of Positions Containing AI Signals in WA", fontsize = 20)
plt.ylim([0,3.7])

plt.legend(loc = 'upper left')

# plotting percentage of positions with AI in Seattle
plt.subplot(1, 2, 2)
plt.bar(ind, AI_positions_Seattle_perc_df.AI_Seattle_22, width, label = "2022 Database")
plt.bar(ind + width, AI_positions_Seattle_perc_df.AI_Seattle_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_positions_Seattle_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16) 
plt.title("Percentage of Positions Containing AI Signals in Seattle Region", fontsize = 20)
plt.ylim([0, 3.7])

plt.legend(loc = 'upper left')
plt.show()

# %%
plt.figure(figsize = (30, 10))

plt.suptitle("2022 Database vs 2025 Database", fontsize = 25)

# plotting percentage of positions with AI in FL
plt.subplot(1, 2, 1)
plt.bar(ind, AI_positions_FL_perc_df.AI_FL_22, width, label = "2022 Database")
plt.bar(ind + width, AI_positions_FL_perc_df.AI_FL_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_positions_FL_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16) 
plt.title("Percentage of Positions Containing AI Signals in FL", fontsize = 20)
plt.ylim([0,1])

plt.legend(loc = 'upper left')

# plotting percentage of positions with AI in Miami
plt.subplot(1, 2, 2)
plt.bar(ind, AI_positions_Miami_perc_df.AI_Miami_22, width, label = "2022 Database")
plt.bar(ind + width, AI_positions_Miami_perc_df.AI_Miami_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_positions_Miami_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16) 
plt.title("Percentage of Positions Containing AI Signals in Miami Region", fontsize = 20)
plt.ylim([0, 1])

plt.legend(loc = 'upper left')
plt.show()

# %%
plt.figure(figsize = (30, 10))

plt.suptitle("2022 Database vs 2025 Database", fontsize = 25)

# plotting percentage of positions with AI in CA
plt.subplot(1, 2, 1)
plt.bar(ind, AI_positions_CA_perc_df.AI_CA_22, width, label = "2022 Database")
plt.bar(ind + width, AI_positions_CA_perc_df.AI_CA_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_positions_CA_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16) 
plt.title("Percentage of Positions Containing AI Signals in CA", fontsize = 20)
plt.ylim([0,2])

plt.legend(loc = 'upper left')

# plotting percentage of positions with AI in San Diego
plt.subplot(1, 2, 2)
plt.bar(ind, AI_positions_SD_perc_df.AI_SD_22, width, label = "2022 Database")
plt.bar(ind + width, AI_positions_SD_perc_df.AI_SD_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_positions_SD_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16) 
plt.title("Percentage of Positions Containing AI Signals in San Diego Region", fontsize = 20)
plt.ylim([0, 2])

plt.legend(loc = 'upper left')
plt.show()

# %%
plt.figure(figsize = (30, 10))

plt.suptitle("2022 Database vs 2025 Database", fontsize = 25)

# plotting percentage of positions with AI in CA
plt.subplot(1, 2, 1)
plt.bar(ind, AI_positions_CA_perc_df.AI_CA_22, width, label = "2022 Database")
plt.bar(ind + width, AI_positions_CA_perc_df.AI_CA_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_positions_CA_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16) 
plt.title("Percentage of Positions Containing AI Signals in CA", fontsize = 20)
plt.ylim([0,2])

plt.legend(loc = 'upper left')

# plotting percentage of positions with AI in Los Angeles
plt.subplot(1, 2, 2)
plt.bar(ind, AI_positions_LA_perc_df.AI_LA_22, width, label = "2022 Database")
plt.bar(ind + width, AI_positions_LA_perc_df.AI_LA_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_positions_LA_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16) 
plt.title("Percentage of Positions Containing AI Signals in Los Angeles Region", fontsize = 20)
plt.ylim([0, 2])

plt.legend(loc = 'upper left')
plt.show()

# %%
plt.figure(figsize = (30, 10))

plt.suptitle("2022 Database vs 2025 Database", fontsize = 25)

# plotting percentage of positions with AI in TX
plt.subplot(1, 2, 1)
plt.bar(ind, AI_positions_TX_perc_df.AI_TX_22, width, label = "2022 Database")
plt.bar(ind + width, AI_positions_TX_perc_df.AI_TX_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_positions_TX_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16) 
plt.title("Percentage of Positions Containing AI Signals in TX", fontsize = 20)
plt.ylim([0,1])

plt.legend(loc = 'upper left')

# plotting percentage of positions with AI in Houston
plt.subplot(1, 2, 2)
plt.bar(ind, AI_positions_Houston_perc_df.AI_Houston_22, width, label = "2022 Database")
plt.bar(ind + width, AI_positions_Houston_perc_df.AI_Houston_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_positions_Houston_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16) 
plt.title("Percentage of Positions Containing AI Signals in Houston Region", fontsize = 20)
plt.ylim([0, 1])

plt.legend(loc = 'upper left')
plt.show()

# %%
plt.figure(figsize = (30, 10))

plt.suptitle("2022 Database vs 2025 Database", fontsize = 25)

# plotting percentage of positions with AI in TX
plt.subplot(1, 2, 1)
plt.bar(ind, AI_positions_TX_perc_df.AI_TX_22, width, label = "2022 Database")
plt.bar(ind + width, AI_positions_TX_perc_df.AI_TX_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_positions_TX_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16) 
plt.title("Percentage of Positions Containing AI Signals in TX", fontsize = 20)
plt.ylim([0,2])

plt.legend(loc = 'upper left')

# plotting percentage of positions with AI in Austin
plt.subplot(1, 2, 2)
plt.bar(ind, AI_positions_Austin_perc_df.AI_Austin_22, width, label = "2022 Database")
plt.bar(ind + width, AI_positions_Austin_perc_df.AI_Austin_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_positions_Austin_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16) 
plt.title("Percentage of Positions Containing AI Signals in Austin Region", fontsize = 20)
plt.ylim([0, 2])

plt.legend(loc = 'upper left')
plt.show()

# %%
plt.figure(figsize = (30, 10))

plt.suptitle("2022 Database vs 2025 Database", fontsize = 25)

# plotting percentage of positions with AI in NY
plt.subplot(1, 2, 1)
plt.bar(ind, AI_positions_NY_perc_df.AI_NY_22, width, label = "2022 Database")
plt.bar(ind + width, AI_positions_NY_perc_df.AI_NY_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_positions_NY_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16) 
plt.title("Percentage of Positions Containing AI Signals in NY", fontsize = 20)
plt.ylim([0,2])

plt.legend(loc = 'upper left')

# plotting percentage of positions with AI in New York City
plt.subplot(1, 2, 2)
plt.bar(ind, AI_positions_NYC_perc_df.AI_NYC_22, width, label = "2022 Database")
plt.bar(ind + width, AI_positions_NYC_perc_df.AI_NYC_25, width, label = "2025 Database")

plt.xticks(ind + width/2, AI_positions_NYC_perc_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16) 
plt.title("Percentage of Positions Containing AI Signals in New York City Region", fontsize = 20)
plt.ylim([0, 2])

plt.legend(loc = 'upper left')
plt.show()

# %%
import plotly.graph_objects as go

fig = go.Figure(data=go.Scattergeo(
        locationmode = 'USA-states',
        lon = AI_positions_cities_geo['lng'],
        lat = AI_positions_cities_geo['lat'],
        text = AI_positions_cities_geo['city'] + ' ' + AI_positions_cities_geo['AI_cities_25'].astype(str),
        mode = 'markers',
        marker = dict(
            size = 10*AI_positions_cities_geo['AI_cities_25'],
            opacity = 0.8,
            reversescale = True,
            autocolorscale = False,
            symbol = 'circle',
            line = dict(
                width=1,
                color='rgba(102, 102, 102)'
            ),
            colorscale = 'agsunset',
            cmin = 0,
            color = AI_positions_cities_geo['AI_cities_25'],
            cmax = AI_positions_cities_geo['AI_cities_25'].max(),
            colorbar=dict(
                title=dict(
                    text="AI %<br>2025 DB"
                )
            )
        )))

fig.update_layout(
        width = 800,
        height = 600,
        title = dict(
            text= 'Percentage of AI Positions in Major US Cities<br>2022 Start Year',
            x = 0.5, 
            xanchor = 'center',
            yanchor =  'top' ),
        geo = dict(
            scope='usa',
            projection_type='albers usa',
            showland = True,
            landcolor = "rgb(250, 250, 250)",
            subunitcolor = "rgb(217, 217, 217)",
            countrycolor = "rgb(217, 217, 217)",
            countrywidth = 2,
            subunitwidth = 2
        ),
    )
fig.show()

# %% [markdown]
# ## Gender Plotting

# %%
plt.figure(figsize = (30, 10))

#plt.suptitle("2022 Database vs 2025 Database", fontsize = 25)

# plotting percentage of positions with AI for woman and men for 2022 DB
plt.subplot(1, 2, 1)
plt.bar(ind, AI_positions_gender_df.AI_F_22, width, label = "Female Users")
plt.bar(ind + width, AI_positions_gender_df.AI_M_22, width, label = "Male Users")

plt.xticks(ind + width/2, AI_positions_gender_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16) 
plt.title("Percentage of Positions Containing AI Signals Across Two Genders \n 2022 DB", fontsize = 20, pad = 20)
plt.ylim([0,1])

plt.legend(loc = 'upper left', fontsize = 15)

# plotting percentage of positions with AI for woman and men for 2025 DB
plt.subplot(1, 2, 2)
plt.bar(ind, AI_positions_gender_df.AI_F_25, width, label = "Female Users")
plt.bar(ind + width, AI_positions_gender_df.AI_M_25, width, label = "Male Users")

plt.xticks(ind + width/2, AI_positions_gender_df.start_years, ha = 'right', rotation = 45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Start Years of Position", fontsize = 16)
plt.ylabel("Percentage of Positions", fontsize = 16) 
plt.title("Percentage of Positions Containing AI Signals Across Two Genders \n 2025 DB", fontsize = 20, pad = 20)
plt.ylim([0, 1])

plt.legend(loc = 'upper left', fontsize = 15)
plt.show()
